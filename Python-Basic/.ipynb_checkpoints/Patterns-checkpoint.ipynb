# %% [markdown]
# ## Patterns
# Refer Patterns PDF

# %%
N = 6
nst = N
row = 1
while row <= N:
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    print()
    row += 1
# Out:
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *

# %%
N = 6
nst = 1
row = 1
while row <= N:
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    nst += 1
    print()
    row += 1
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
N = 6
nst = N
row = 1
while row <= N:
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    nst -= 1
    print()
    row += 1
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
N = 5
row = 1
nsp = N-1
nst = 1

while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1
    nsp -= 1
    nst += 1
    print()
    row += 1
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
N = 5
row = 1
nsp = 0
nst = N

while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1
    nsp += 1
    nst -= 1
    print()
    row += 1
# Out:
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %%
N = 5
row = 1
nsp = 0
nst = N

while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1
    nsp += 2
    nst -= 1
    print()
    row += 1
# Out:
# * * * * *
#     * * * *
#         * * *
#             * *
#                 *

# %%
N = 5
row = 1
nsp = N-1
nst = 1

while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1
    nsp -= 1
    nst += 2
    print()
    row += 1
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
N = 5
row = 1
nsp = 0
nst = 2*N-1

while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1
    nsp += 1
    nst -= 2
    print()
    row += 1
# Out:
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %%
N = 5
row = 1
nsp = N-1
nst = 1

while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    while cst <= nst:
        if cst%2 != 0:
            print('*',end = ' ')
        else:
            print('!',end = ' ')
        cst += 1
    nsp -= 1
    nst += 2
    print()
    row += 1
# Out:
#         *
#       * ! *
#     * ! * ! *
#   * ! * ! * ! *
# * ! * ! * ! * ! *

# %%
N = 6
nst = N
row = 1
while row <= N:
    cst = 1
    while cst <= nst:
        if row == 1 or row == N or cst == 1 or cst == N:
            print('*',end = ' ')
        else:
            print(' ' ,end = ' ')
        cst += 1

    print()
    row += 1
# Out:
# * * * * * *
# *         *
# *         *
# *         *
# *         *
# * * * * * *

# %%
N = 5
nst = N
row = 1
while row <= N:
    cst = 1
    while cst <= nst:
        if row == cst or cst+row == N+1:
            print('*',end = ' ')
        else:
            print(' ' ,end = ' ')
        cst += 1

    print()
    row += 1
# Out:
# *       *
#   *   *
#     *
#   *   *
# *       *

# %%
N = 6
nst = 1
row = 1
while row <= 2*N-1:
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    if row < N:
        nst += 1
    else:
        nst -= 1
    print()
    row += 1
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
N = 6
nst = 1
nsp = N-1
row = 1
while row <= 2*N-1:
    csp = 1
    while csp <= nsp:
        print(" ",end= " ")
        csp += 1
        
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    if row < N:
        nst += 1
        nsp -= 1
    else:
        nst -= 1
        nsp += 1
    print()
    row += 1
# Out:
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *
# * * * * * *
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *

# %%
N = 6
nst = N
nsp = 0
row = 1
while row <= 2*N-1:
    csp = 1
    while csp <= nsp:
        print(" ",end= " ")
        csp += 1
        
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    if row < N:
        nst -= 1
        nsp += 2
    else:
        nst += 1
        nsp -= 2
    print()
    row += 1
# Out:
# * * * * * *
#     * * * * *
#         * * * *
#             * * *
#                 * *
#                     *
#                 * *
#             * * *
#         * * * *
#     * * * * *
# * * * * * *

# %%
N = 6
nst = N
nsp = N-1
row = 1
while row <= 2*N-1:
    csp = 1
    while csp <= nsp:
        print(" ",end= " ")
        csp += 1
        
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    if row < N:
        nst -= 1
        nsp -= 1
    else:
        nst += 1
        nsp += 1
    print()
    row += 1
# Out:
#           * * * * * *
#         * * * * *
#       * * * *
#     * * *
#   * *
# *
#   * *
#     * * *
#       * * * *
#         * * * * *
#           * * * * * *

# %%
N = 7
nst = 1
nsp = N//2
row = 1
while row <= N:
    csp = 1
    while csp <= nsp:
        print(" ",end= " ")
        csp += 1
        
    cst = 1
    while cst <= nst:
        print('*',end = ' ')
        cst += 1

    if row <= N//2:
        nst += 2
        nsp -= 1
    else:
        nst -= 2
        nsp += 1
    print()
    row += 1
# Out:
#       *
#     * * *
#   * * * * *
# * * * * * * *
#   * * * * *
#     * * *
#       *

# %%
N = 7
row = 1
nsp = -1
nst = N//2+1
while row <= N:
    cst = 1
    while cst <= nst:
        print("*",end=" ")
        cst += 1

    csp = 1
    while csp <= nsp:
        print(" ",end = " ")
        csp += 1

    cst = 1
    if row == 1 or row == N:
        cst = 2
    while cst <= nst:
        print("*",end=" ")
        cst += 1

    if row <= N//2:
        nst -= 1
        nsp += 2
    else:
        nst += 1
        nsp -= 2

    row += 1
    print()
# Out:
# * * * * * * *
# * * *   * * *
# * *       * *
# *           *
# * *       * *
# * * *   * * *
# * * * * * * *

# %%
N = 5
row = 1
nsp = N-1
nst = 1

while row <= 2*N-1:
    csp = 1
    while csp <= nsp:
        print(" " ,end= " ")
        csp += 1
    
    cst = 1
    while cst <= nst:
        print("*",end = " ")
        cst += 1

    if row < N:
        nst += 1
        nsp -= 1
    else:
        nst -= 1
        nsp += 1

    row += 1
    print()
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %%
N = 7
row = 1
nst = N//2
nsp = 1
while row <= N:
    cst = 1
    while cst <= nst:
        print("*",end = " ")
        cst += 1
    
    csp = 1
    while csp <= nsp:
        print(" " ,end= " ")
        csp += 1

    cst = 1
    while cst <= nst:
        print("*",end = " ")
        cst += 1

    if row <= N//2:
        nsp += 2
        nst -= 1
    else:
        nst += 1
        nsp -= 2
    row += 1
    print()
# Out:
# * * *   * * * * *       * * *           *
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      11 csp = 1
#      12 while csp <= nsp:
# ---> 13     print(" " ,end= " ")
#      14     csp += 1
#      16 cst = 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\iostream.py:684, in OutStream.write(self, string)
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
# --> 684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#     688     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:
