# %%
import cv2
import matplotlib.pyplot as plt

# %%
cv2.__version__
import numpy as np
np.__version__
# Out:
# '1.26.4'

# %%
img = cv2.imread("./dog.png")
# new_img = img[:,:,::-1]
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(new_img)

# %%
image = cv2.imread('./dog.png',cv2.IMREAD_GRAYSCALE)

# %%
print(image.shape)
# Out:
# (512, 512)

# %%
plt.imshow(gray,cmap='gray')

# %%
faces = [(1,2,3,4),(4,3,5,6),(7,8,1,2)]

# %%
sorted(faces,key = lambda f: f[2]*f[3])[-1]
# Out:
# (4, 3, 5, 6)

# %%
import os
import numpy as np
